# %% [markdown]
# # Generate a folder with a python file

# %%
import os 
import sys

# %%
#os.mkdir('src')
os.mkdir('docs')

# %%
# %%writefile docs/pyplots/ellipses.py

from pylab import xlim, ylim, arange, subplot, show
from matplotlib.patches import Ellipse

delta = 45.0 # degrees

angles = arange(0, 360+delta, delta)
ells = [Ellipse((1, 1), 4, 2, a) for a in angles]

a = subplot(111, aspect='equal')

for e in ells:
    e.set_clip_box(a.bbox)
    e.set_alpha(0.1)
    a.add_artist(e)

xlim(-2, 4)
ylim(-1, 3)

show()
# Out:
# Overwriting docs/pyplots/ellipses.py

# %% [markdown]
# ### apyfile.py

# %%
# %%writefile src/apyfile.py

from pylab import xlim, ylim


def funci(x):
    """Here is something new
    Hallo hallo.
    I am a docstring! 
    
    You can represent code blocks fairly easily::

       import numpy as np
       x = np.random.rand(12)
       print x

    .. math::
        \int f(x)~dx 
    .. note::
       Michse beautiful
       you too
    .. seealso:: This is a simple **seealso** note.
    .. warning::
       never use me!
    .. todo:: 
       This is a todo!
       
       
    .. plot:: pyplots/scatter_tooltip.py
       :include-source:
    
    Full path: 
    
    .. raw:: html
    
        <div style="margin-top:10px;">
        <iframe width="700" height="500"scrolling="no" frameborder="0" src="E:/IPython2/141007 Sphinx and ShapelyChipDesigns/try4/docs/pyplots/img/scatter_plot.html"></iframe>
        </div>
        
    "pyplots/img/scatter_plot.html" 
    
    .. raw:: html

        <div style="margin-top:10px;">
        <iframe width="700" height="500"scrolling="no" frameborder="0" src="pyplots/img/scatter_plot.html"></iframe>
        </div>
        
    "../pyplots/img/scatter_plot.html" 
    
    .. raw:: html

        <div style="margin-top:10px;">
        <iframe width="700" height="500"scrolling="no" frameborder="0" src="../pyplots/img/scatter_plot.html"></iframe>
        </div>
        
    "../../pyplots/img/scatter_plot.html
    
    .. raw:: html

        <div style="margin-top:10px;">
        <iframe width="700" height="500"scrolling="no" frameborder="0" src="../../pyplots/img/scatter_plot.html"></iframe>
        </div>

    "../../../src/_img/scatter_plot.html
    
    .. raw:: html

        <div style="margin-top:10px;">
        <iframe width="700" height="500"scrolling="no" frameborder="0" src="../../../src/_img/scatter_plot.html"></iframe>
        </div>
       
    .. raw:: html

        <div style="margin-top:10px;">
          <iframe width="560" height="315" src="http://www.youtube.com/embed/_EjisXtMy_Y" frameborder="0" allowfullscreen></iframe>
        </div>
    
    .. doctest::

        >>> import math
        >>> print math.sqrt(2.)
        1.41421356237
       
    .. plot:: pyplots/ellipses.py
       :include-source:
       
    .. plot:: pyplots/test_mpld3.py
       :include-source:
       
    .. image:: pyplots/img/scatter_plot.png

    .. _ipython-highlighting:
    .. sourcecode:: ipython

        In [69]: lines = plot([1,2,3])

        In [70]: setp(lines)
          alpha: float
          animated: [True | False]
          antialiased or aa: [True | False]
          ...snip
    
    You can also inline code for plots directly, and the code will be
    executed at documentation build time and the figure inserted into your
    docs; the following code::

       .. plot::

          import matplotlib.pyplot as plt
          import numpy as np
          x = np.random.randn(1000)
          plt.hist( x, 20)
          plt.grid()
          plt.title(r'Normal: $\mu=%.2f, \sigma=%.2f$'%(x.mean(), x.std()))
          plt.show()

    Produces this output: 
    
    .. plot::
    
        import matplotlib.pyplot as plt
        import numpy as np
        x = np.random.randn(1000)
        plt.hist( x, 20)
        plt.grid()
        plt.title(r'Normal: $\mu=%.2f, \sigma=%.2f$'%(x.mean(), x.std()))
        plt.show()
       
    Lalal: 
       import matplotlib.pyplot as plt
        import numpy as np
        x = np.random.randn(1000)
        plt.hist( x, 20)
        plt.grid()
        plt.title(r'Normal: $\mu=%.2f, \sigma=%.2f$'%(x.mean(), x.std()))
        plt.show()
    """
    return 0
# Out:
# Writing src/apyfile.py

# %% [markdown]
# ### A) Generate

# %%
# !sphinx-apidoc -f -F --maxdepth=2 -e -V "0.0.0" -H "ShapelyChipDesigns" -A "Hambi" -o "E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs" "E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\src"
# Out:
# Creating file E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\apyfile.rst.
# Creating file E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\examples.rst.
# Creating file E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\ShapelyChipDesigns.allparts.rst.
# Creating file E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\ShapelyChipDesigns.brandnew_structure.rst.
# Creating file E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\ShapelyChipDesigns.designs_poly.rst.
# Creating file E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\ShapelyChipDesigns.designs_xy.rst.
# Creating file E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\ShapelyChipDesigns.finger_capacitor.rst.
# Creating file E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\ShapelyChipDesigns.groundplane.rst.
# Creating file E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\ShapelyChipDesigns.helpers.rst.
# Creating file E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\ShapelyChipDesigns.in_out_show.rst.
# Creating file E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\ShapelyChipDesigns.shapely_fonts.rst.
# Creating file E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\ShapelyChipDesigns.smooth.rst.
# Creating file E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\ShapelyChipDesigns.rst.
# Creating file E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\conf.py.
# Creating file E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\index.rst.
# Creating file E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\Makefile.
# Creating file E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\make.bat.

# %% [markdown]
# ### B) Modify conf.py

# %%
# %%writefile -a docs/conf.py

sys.path.insert(0, os.path.abspath('../src'))
sys.path.append(os.path.abspath('sphinxext/plot_generator.py'))
sys.path.append(os.path.abspath('sphinxext'))
print os.path.abspath('sphinxext/plot_generator.py')

extensions = [
          'matplotlib.sphinxext.mathmpl',
          'matplotlib.sphinxext.only_directives',
          'matplotlib.sphinxext.plot_directive',
          'matplotlib.sphinxext.ipython_directive',
          'IPython.sphinxext.ipython_console_highlighting',
          'sphinx.ext.autodoc',
          'sphinx.ext.doctest',
          'sphinx.ext.todo',
          'sphinx.ext.autosummary']
          #'numpydoc'

[extensions]
todo_include_todos=True

import numpy_ext.numpydoc
extensions.append('numpy_ext.numpydoc')

import plot_generator
extensions.append('plot_generator')

import notebook_converter
extensions.append('notebook_converter')

def skip_modules_docstring(app, what, name, obj, options, lines):
    if what in []:
        del lines[:]

def setup(app):
    app.connect('autodoc-process-docstring', skip_modules_docstring)
    
import sphinx_bootstrap_theme

# ...

# Activate the theme.
html_theme = 'bootstrap'
html_theme_path = sphinx_bootstrap_theme.get_html_theme_path()
    
#html_theme = 'mpld3'
#html_theme_path = ['themes']
# Out:
# Appending to docs/conf.py

# %% [markdown]
# ### D) make

# %%
# %%cmd
# cd docs
# make clean
# make html
# make
# Out:
# Microsoft Windows [Version 6.1.7601]
# Copyright (c) 2009 Microsoft Corporation.  All rights reserved.
#
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4>cd docs
#
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs>make clean
#
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs>make html
# Making output directory...
# Running Sphinx v1.2.2
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\sphinxext\plot_generator.py
# loading pickled environment... not yet created
# building [html]: targets for 24 source files that are out of date
# updating environment: 24 added, 0 changed, 0 removed
# reading sources... [  4%] E1_E3
# reading sources... [  8%] Introduction
# reading sources... [ 12%] ShapelyChipDesigns
# reading sources... [ 16%] ShapelyChipDesigns.allparts
# reading sources... [ 20%] ShapelyChipDesigns.brandnew_structure
# reading sources... [ 25%] ShapelyChipDesigns.designs_poly
# reading sources... [ 29%] ShapelyChipDesigns.designs_xy
# reading sources... [ 33%] ShapelyChipDesigns.finger_capacitor
# reading sources... [ 37%] ShapelyChipDesigns.groundplane
# reading sources... [ 41%] ShapelyChipDesigns.helpers
# reading sources... [ 45%] ShapelyChipDesigns.in_out_show
# reading sources... [ 50%] ShapelyChipDesigns.shapely_fonts
# reading sources... [ 54%] ShapelyChipDesigns.smooth
# reading sources... [ 58%] apyfile
# reading sources... [ 62%] brandnew_structure
# reading sources... [ 66%] examples
# reading sources... [ 70%] examples/index
# reading sources... [ 75%] finger_capacitor
# reading sources... [ 79%] hello
# reading sources... [ 83%] helpers
# reading sources... [ 87%] in_out_show
# reading sources... [ 91%] index
# reading sources... [ 95%] notebooks/index
# reading sources... [100%] test_mpld3
#
# looking for now-outdated files... none found
# pickling environment... done
# checking consistency... done
# preparing documents... done
# writing output... [  4%] E1_E3
# writing output... [  8%] Introduction
# writing output... [ 12%] ShapelyChipDesigns
# writing output... [ 16%] ShapelyChipDesigns.allparts
# writing output... [ 20%] ShapelyChipDesigns.brandnew_structure
# writing output... [ 25%] ShapelyChipDesigns.designs_poly
# writing output... [ 29%] ShapelyChipDesigns.designs_xy
# writing output... [ 33%] ShapelyChipDesigns.finger_capacitor
# writing output... [ 37%] ShapelyChipDesigns.groundplane
# writing output... [ 41%] ShapelyChipDesigns.helpers
# writing output... [ 45%] ShapelyChipDesigns.in_out_show
# writing output... [ 50%] ShapelyChipDesigns.shapely_fonts
# writing output... [ 54%] ShapelyChipDesigns.smooth
# ##################################################################################################writing output... [ 58%] apyfile
# #writing output... [ 62%] brandnew_structure
# writing output... [ 66%] examples
# writing output... [ 70%] examples/index
# writing output... [ 75%] finger_capacitor
# writing output... [ 79%] hello
# ###writing output... [ 83%] helpers
# writing output... [ 87%] in_out_show
# writing output... [ 91%] index
# writing output... [ 95%] notebooks/index
# writing output... [100%] test_mpld3
#
# writing additional files... genindex py-modindex np-modindex search
# copying images... [  4%] pyplots/img/scatter_plot.png
# copying images... [  9%] E1_E3_files/E1_E3_20_0.png
# copying images... [ 13%] E1_E3_files/E1_E3_25_0.png
# copying images... [ 18%] E1_E3_files/E1_E3_48_0.png
# copying images... [ 22%] images/Introduction_fig00.png
# copying images... [ 27%] E1_E3_files/E1_E3_12_0.png
# copying images... [ 31%] E1_E3_files/E1_E3_29_1.png
# copying images... [ 36%] _build/plot_directive/apyfile-1.png
# copying images... [ 40%] _build/plot_directive/pyplots/scatter_tooltip.png
# copying images... [ 45%] Introduction_files/Introduction_10_0.png
# copying images... [ 50%] Introduction_files/Introduction_9_0.png
# copying images... [ 54%] _build/plot_directive/pyplots/ellipses.png
# copying images... [ 59%] hello_files/hello_3_1.png
# copying images... [ 63%] Introduction_files/Introduction_7_0.png
# copying images... [ 68%] E1_E3_files/E1_E3_10_1.png
# copying images... [ 72%] Introduction_files/Introduction_14_1.png
# copying images... [ 77%] E1_E3_files/E1_E3_18_0.png
# copying images... [ 81%] images/Introduction_fig01.png
# copying images... [ 86%] E1_E3_files/E1_E3_7_1.png
# copying images... [ 90%] Introduction_files/Introduction_8_1.png
# copying images... [ 95%] E1_E3_files/E1_E3_9_0.png
# copying images... [100%] _build/plot_directive/examples/example_EBL_markers.png
#
# copying static files... done
# copying extra files... done
# dumping search index... done
# dumping object inventory... done
# build succeeded, 33 warnings.
#
# Build finished. The HTML pages are in _build/html.
#
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs>More?
# C:\Python27\lib\site-packages\IPython\lib\kernel.py:8: DeprecationWarning: IPython.lib.kernel moved to IPython.kernel.connect in IPython 1.0
#   DeprecationWarning
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\E1_E3.rst:74: WARNING: Explicit markup ends without a blank line; unexpected unindent.
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\E1_E3.rst:1886: WARNING: Explicit markup ends without a blank line; unexpected unindent.
# [u'get_airbridge_polys(x, y, A10, A20, NA=10, res=1000.0)', u':module: ShapelyChipDesigns.designs_poly', u'', u'', u'', u'x,y: coordinates along which to distribute the airbridges', u'NA:  number of airbridges', u'A10, A20: Airbridge Polygons (A20 is the larger one), use ', u'    "get_airbridge_poly" to get the boxes', u'returns S1, S2 airbridge layers. ']:6: ERROR: Unexpected indentation.
# <autodoc>:0: WARNING: Block quote ends without a blank line; unexpected unindent.
# <autodoc>:0: WARNING: Definition list ends without a blank line; unexpected unindent.
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\brandnew_structure.rst:4: WARNING: autodoc: failed to import module u'brandnew_structure'; the following exception was raised:
# Traceback (most recent call last):
#   File "C:\Python27\lib\site-packages\sphinx\ext\autodoc.py", line 335, in import_object
#     __import__(self.modname)
# ImportError: No module named brandnew_structure
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\finger_capacitor.rst:4: WARNING: autodoc: failed to import module u'finger_capacitor'; the following exception was raised:
# Traceback (most recent call last):
#   File "C:\Python27\lib\site-packages\sphinx\ext\autodoc.py", line 335, in import_object
#     __import__(self.modname)
# ImportError: No module named finger_capacitor
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\helpers.rst:4: WARNING: autodoc: failed to import module u'helpers'; the following exception was raised:
# Traceback (most recent call last):
#   File "C:\Python27\lib\site-packages\sphinx\ext\autodoc.py", line 335, in import_object
#     __import__(self.modname)
# ImportError: No module named helpers
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\in_out_show.rst:4: WARNING: autodoc: failed to import module u'in_out_show'; the following exception was raised:
# Traceback (most recent call last):
#   File "C:\Python27\lib\site-packages\sphinx\ext\autodoc.py", line 335, in import_object
#     __import__(self.modname)
# ImportError: No module named in_out_show
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\index.rst:139: WARNING: toctree contains reference to nonexisting document u'Installation'
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\index.rst:139: WARNING: toctree contains reference to nonexisting document u' .. raw:: html'
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\index.rst:139: WARNING: toctree contains reference to nonexisting document u'div style="margin-top:10px;"'
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\index.rst:139: WARNING: toctree contains reference to nonexisting document u'SDdocsInstallation.html"></iframe'
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\index.rst:139: WARNING: toctree contains reference to nonexisting document u'div'
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\index.rst:139: WARNING: toctree contains reference to nonexisting document u'Installation'
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\index.rst:139: WARNING: toctree contains reference to nonexisting document u' .. raw:: html'
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\index.rst:139: WARNING: toctree contains reference to nonexisting document u'div style="margin-top:10px;"'
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\index.rst:139: WARNING: toctree contains reference to nonexisting document u'iframe scrolling="yes" frameborder="0" src="E:/IPython2/141007 Sphinx and ShapelyChipDesigns/try4/docs/SDdocsInstallation.html"></iframe'
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\index.rst:139: WARNING: toctree contains reference to nonexisting document u'div'
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\index.rst:139: WARNING: toctree contains reference to nonexisting document u'Installation'
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\index.rst:139: WARNING: toctree contains reference to nonexisting document u' .. raw:: html'
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\index.rst:139: WARNING: toctree contains reference to nonexisting document u'div style="margin-top:10px;"'
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\index.rst:139: WARNING: toctree contains reference to nonexisting document u'iframe scrolling="yes" frameborder="0" src="E:/IPython2/141007 Sphinx and ShapelyChipDesigns/try4/docs/SDdocsInstallation.html"></iframe'
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\index.rst:139: WARNING: toctree contains reference to nonexisting document u'div'
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\test_mpld3.rst:4: WARNING: autodoc: failed to import module u'test_mpld3'; the following exception was raised:
# Traceback (most recent call last):
#   File "C:\Python27\lib\site-packages\sphinx\ext\autodoc.py", line 335, in import_object
#     __import__(self.modname)
# ImportError: No module named test_mpld3
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\brandnew_structure.rst:: WARNING: document isn't included in any toctree
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\examples\index.rst:: WARNING: document isn't included in any toctree
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\finger_capacitor.rst:: WARNING: document isn't included in any toctree
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\hello.rst:: WARNING: document isn't included in any toctree
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\helpers.rst:: WARNING: document isn't included in any toctree
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\in_out_show.rst:: WARNING: document isn't included in any toctree
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\notebooks\index.rst:: WARNING: document isn't included in any toctree
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs\test_mpld3.rst:: WARNING: document isn't included in any toctree
# C:\Python27\lib\site-packages\matplotlib\sphinxext\mathmpl.py:57: Warning: Could not render math expression $0 \le x \le m$
#   Warning)
# C:\Python27\lib\site-packages\matplotlib\sphinxext\mathmpl.py:57: Warning: Could not render math expression $n+m-N \le x \le n$
#   Warning)
# C:\Python27\lib\site-packages\matplotlib\sphinxext\mathmpl.py:57: Warning: Could not render math expression $P(x; x_0, \gamma) = \frac{1}{\pi \gamma \bigl[ 1+(\frac{x-x_0}{\gamma})^2 \bigr] }$
#   Warning)
# C:\Python27\lib\site-packages\matplotlib\sphinxext\mathmpl.py:57: Warning: Could not render math expression $P(x, df) = \frac{\Gamma(\frac{df+1}{2})}{\sqrt{\pi df}\Gamma(\frac{df}{2})}\Bigl( 1+\frac{x^2}{df} \Bigr)^{-(df+1)/2}$
#   Warning)
# C:\Python27\lib\site-packages\matplotlib\sphinxext\mathmpl.py:57: Warning: Could not render math expression $P(x;l, m, r) = \begin{cases}\frac{2(x-l)}{(r-l)(m-l)}& \text{for $l \leq x \leq m$},\\\frac{2(m-x)}{(r-l)(r-m)}& \text{for $m \leq x \leq r$},\\0& \text{otherwise}.\end{cases}$
#   Warning)

# %% [markdown]
# ### C) index.rst - modifications

# %%
Intro = """
ShapelyChipDesigns can be used to gather and manipulate geometric objects.

It is based on the Shapely-Package and mainly uses a class called BRANDNEWOBJECT:

    "../../pyplots/img/E1_E3.html

.. raw:: html

    <div style="margin-top:10px;">
    <iframe width="800" height="350"scrolling="no" frameborder="0" src="../../pyplots/img/E1_E3.html"></iframe>
    </div>

    "../../pyplots/img/scatter_plot.html

.. raw:: html

    <div style="margin-top:10px;">
    <iframe width="700" height="500" scrolling="no" frameborder="0" src="../../pyplots/img/scatter_plot.html"></iframe>
    </div>

.. image:: images/Introduction_fig00.png

One BRANDNEWOBJECT can contain many Polygons on different layers. 
Global geometric operations such as rotations, translations and scaling can be used to manipulate all Polygons in the BRANDNEWOBJECT container at once.

Further anker points can be added, which will be affected by all this operations as well. 
Therefore if you want to attach one BRANDNEWOBJECT to another, you can just design them seperately and later attach them at the desired ANKER points:

This might be the 'important_dot' in the sketch above.

Here the circle is scaled, rotated and translated - the polygons are kept together and the important anker point is moving with the object:

.. image:: images/Introduction_fig01.png

.. raw:: html

    <div style="margin-top:10px;">
    <iframe width="700" height="500" scrolling="no" frameborder="0" src="../../SDdocsInstallation.html"></iframe>
    </div>
    
    <div style="margin-top:10px;">
    <iframe scrolling="yes" frameborder="0" src="../../SDdocsInstallation.html"></iframe>
    </div>

"""

# %%
html_files = [
"""
    .. raw:: html
    
        <div style="margin-top:10px;">
        <iframe scrolling="yes" frameborder="0" src="../../SDdocsInstallation.html"></iframe>
        </div>
""",
]

# %%
additional_contents = ['   Introduction',
                       '   Installation', 
                       html_files[0],
                       '   E1_E3']

from pylab import flatten

f = open('docs/index.rst', 'r')
content = f.read()
f.close()

lines = content.splitlines()
for i, line in enumerate(lines): 
    if line == "Welcome to ShapelyChipDesigns's documentation!":
        lines.insert(i+2, Intro)
    if line == '.. toctree::':
        lines.insert(i+3, additional_contents) 
        
lines = list(flatten(lines))
lines = [l+'\n' for l in lines]

f = open('docs/index.rst', 'w')
f.writelines(lines)
f.close()

# %%
# %%cmd
# cd docs
# make doctest
# make
# Out:
# Microsoft Windows [Version 6.1.7601]
# Copyright (c) 2009 Microsoft Corporation. Alle Rechte vorbehalten.
#
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4>cd docs
#
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs>make doctest
# Making output directory...
# Running Sphinx v1.2.2
# loading pickled environment... done
# building [doctest]: targets for 6 source files that are out of date
# updating environment: 0 added, 0 changed, 0 removed
# looking for now-outdated files... none found
# running tests...
#
# Document: apyfile
# -----------------
# 1 items passed all tests:
#    2 tests in default
# 2 tests in 1 items.
# 2 passed and 0 failed.
# Test passed.
#
# Doctest summary
# ===============
#     2 tests
#     0 failures in tests
#     0 failures in setup code
#     0 failures in cleanup code
# build succeeded.
#
# Testing of doctests in the sources finished, look at the results in _build/doctest/output.txt.
#
# E:\IPython2\141007 Sphinx and ShapelyChipDesigns\try4\docs>Mehr?

# %%
sys.path
# Out:
# ['',
#  'C:\\Python27\\lib\\site-packages\\numpydoc-0.5-py2.7.egg',
#  'C:\\windows\\system32\\python27.zip',
#  'C:\\Python27\\DLLs',
#  'C:\\Python27\\lib',
#  'C:\\Python27\\lib\\plat-win',
#  'C:\\Python27\\lib\\lib-tk',
#  'C:\\Python27',
#  'C:\\Python27\\lib\\site-packages',
#  'C:\\Python27\\lib\\site-packages\\win32',
#  'C:\\Python27\\lib\\site-packages\\win32\\lib',
#  'C:\\Python27\\lib\\site-packages\\Pythonwin',
#  'C:\\Python27\\lib\\site-packages\\wx-2.8-msw-unicode',
#  'C:\\Python27\\lib\\site-packages\\IPython\\extensions']
